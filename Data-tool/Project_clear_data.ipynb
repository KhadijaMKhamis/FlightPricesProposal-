# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
flight = pd.read_csv(r'itineraries.csv',nrows=5000000)
flight
# Out:
#                                     legId  searchDate  flightDate  \
# 0        9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17
# 1        98685953630e772a098941b71906592b  2022-04-16  2022-04-17
# 2        98d90cbc32bfbb05c2fc32897c7c1087  2022-04-16  2022-04-17
# 3        969a269d38eae583f455486fa90877b4  2022-04-16  2022-04-17
# 4        980370cf27c89b40d2833a1d5afc9751  2022-04-16  2022-04-17
# ...                                   ...         ...         ...
# 4999995  c7f6bfaf38d3116b1d0bc2db5a23b435  2022-04-27  2022-06-16
# 4999996  6e80834f62e373808231583b74dd95c9  2022-04-27  2022-06-16
# 4999997  8c8fd3a8c548f59c90086248a73c8856  2022-04-27  2022-06-16
# 4999998  42a1d959893ba5ba25bffe73535f50dd  2022-04-27  2022-06-16
# 4999999  33a30fd96281191ce212e97478c24e93  2022-04-27  2022-06-16
#
#         startingAirport destinationAirport fareBasisCode travelDuration  \
# 0                   ATL                BOS      LA0NX0MC        PT2H29M
# ...

# %%
flight.head()
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17             ATL
# 1  98685953630e772a098941b71906592b  2022-04-16  2022-04-17             ATL
# 2  98d90cbc32bfbb05c2fc32897c7c1087  2022-04-16  2022-04-17             ATL
# 3  969a269d38eae583f455486fa90877b4  2022-04-16  2022-04-17             ATL
# 4  980370cf27c89b40d2833a1d5afc9751  2022-04-16  2022-04-17             ATL
#
#   destinationAirport fareBasisCode travelDuration  elapsedDays  \
# 0                BOS      LA0NX0MC        PT2H29M            0
# 1                BOS      LA0NX0MC        PT2H30M            0
# 2                BOS      LA0NX0MC        PT2H30M            0
# 3                BOS      LA0NX0MC        PT2H32M            0
# 4                BOS      LA0NX0MC        PT2H34M            0
#
#    isBasicEconomy  isRefundable  ...  segmentsArrivalTimeEpochSeconds  \
# ...

# %%
flight.head(10)
# Out:
#                               legId  searchDate  flightDate startingAirport  \
# 0  9ca0e81111c683bec1012473feefd28f  2022-04-16  2022-04-17             ATL
# 1  98685953630e772a098941b71906592b  2022-04-16  2022-04-17             ATL
# 2  98d90cbc32bfbb05c2fc32897c7c1087  2022-04-16  2022-04-17             ATL
# 3  969a269d38eae583f455486fa90877b4  2022-04-16  2022-04-17             ATL
# 4  980370cf27c89b40d2833a1d5afc9751  2022-04-16  2022-04-17             ATL
# 5  79eda9f841e226a1e2121d74211e595c  2022-04-16  2022-04-17             ATL
# 6  9335fae376c38bb61263281779f469ec  2022-04-16  2022-04-17             ATL
# 7  3904bf87f2d1daf334f1ae7e3b876028  2022-04-16  2022-04-17             ATL
# 8  d93988734c44a3c075d9efe373352507  2022-04-16  2022-04-17             ATL
# 9  562e7d5dd6ecbf1509c0c19711dbdca9  2022-04-16  2022-04-17             ATL
#
#   destinationAirport fareBasisCode travelDuration  elapsedDays  \
# 0                BOS      LA0NX0MC        PT2H29M            0
# ...

# %%
flight.tail()
# Out:
#                                     legId  searchDate  flightDate  \
# 4999995  c7f6bfaf38d3116b1d0bc2db5a23b435  2022-04-27  2022-06-16
# 4999996  6e80834f62e373808231583b74dd95c9  2022-04-27  2022-06-16
# 4999997  8c8fd3a8c548f59c90086248a73c8856  2022-04-27  2022-06-16
# 4999998  42a1d959893ba5ba25bffe73535f50dd  2022-04-27  2022-06-16
# 4999999  33a30fd96281191ce212e97478c24e93  2022-04-27  2022-06-16
#
#         startingAirport destinationAirport fareBasisCode travelDuration  \
# 4999995             LAX                DFW      QAA0OKEN        PT5H46M
# 4999996             LAX                DFW      QAA0OKEN        PT7H13M
# 4999997             LAX                DFW      UAA0OQEN        PT5H50M
# 4999998             LAX                DFW      UAA0OQEN        PT5H43M
# 4999999             LAX                DFW      HAA0OKEN        PT5H22M
#
#          elapsedDays  isBasicEconomy  isRefundable  ...  \
# 4999995            0           False         False  ...
# ...

# %%
flight.sample(5)
# Out:
#                                     legId  searchDate  flightDate  \
# 537350   96aa0b316b0ec498d9b77cbaeb051369  2022-04-17  2022-06-07
# 1194284  d599e84f4ca47e66c2e614db742e8c5c  2022-04-19  2022-05-02
# 4472103  abff7048d32ec9f47eafe5f16d0ae7bb  2022-04-26  2022-05-20
# 2476669  cfe277a998eb689b031368700d4d71c4  2022-04-22  2022-04-25
# 984414   e516445fdcebbf4f0a24ad90c286a48c  2022-04-18  2022-05-28
#
#         startingAirport destinationAirport fareBasisCode travelDuration  \
# 537350              IAD                JFK      G7AHZNN1        PT8H39M
# 1194284             LGA                SFO      OL7AUEL1        PT9H34M
# 4472103             DEN                OAK      TAVNA0BC        PT4H31M
# 2476669             BOS                LAX      VAA3KKEN        PT8H58M
# 984414              SFO                EWR      MAUNA0MC        PT6H49M
#
#          elapsedDays  isBasicEconomy  isRefundable  ...  \
# 537350             0           False         False  ...
# ...

# %%
flight.shape
# Out:
# (5000000, 27)

# %%
flight.size
# Out:
# 135000000

# %%
flight.dtypes
# Out:
# legId                                 object
# searchDate                            object
# flightDate                            object
# startingAirport                       object
# destinationAirport                    object
# fareBasisCode                         object
# travelDuration                        object
# elapsedDays                            int64
# isBasicEconomy                          bool
# isRefundable                            bool
# isNonStop                               bool
# baseFare                             float64
# totalFare                            float64
# seatsRemaining                         int64
# totalTravelDistance                  float64
# segmentsDepartureTimeEpochSeconds     object
# segmentsDepartureTimeRaw              object
# segmentsArrivalTimeEpochSeconds       object
# segmentsArrivalTimeRaw                object
# segmentsArrivalAirportCode            object
# segmentsDepartureAirportCode          object
# ...

# %%
flight.index
# Out:
# RangeIndex(start=0, stop=5000000, step=1)

# %%
flight.columns
# Out:
# Index(['legId', 'searchDate', 'flightDate', 'startingAirport',
#        'destinationAirport', 'fareBasisCode', 'travelDuration', 'elapsedDays',
#        'isBasicEconomy', 'isRefundable', 'isNonStop', 'baseFare', 'totalFare',
#        'seatsRemaining', 'totalTravelDistance',
#        'segmentsDepartureTimeEpochSeconds', 'segmentsDepartureTimeRaw',
#        'segmentsArrivalTimeEpochSeconds', 'segmentsArrivalTimeRaw',
#        'segmentsArrivalAirportCode', 'segmentsDepartureAirportCode',
#        'segmentsAirlineName', 'segmentsAirlineCode',
#        'segmentsEquipmentDescription', 'segmentsDurationInSeconds',
#        'segmentsDistance', 'segmentsCabinCode'],
#       dtype='object')

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 27 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   legId                              object
#  1   searchDate                         object
#  2   flightDate                         object
#  3   startingAirport                    object
#  4   destinationAirport                 object
#  5   fareBasisCode                      object
#  6   travelDuration                     object
#  7   elapsedDays                        int64
#  8   isBasicEconomy                     bool
#  9   isRefundable                       bool
#  10  isNonStop                          bool
#  11  baseFare                           float64
#  12  totalFare                          float64
#  13  seatsRemaining                     int64
#  14  totalTravelDistance                float64
#  15  segmentsDepartureTimeEpochSeconds  object
# ...

# %%
flight.describe()
# Out:
#         elapsedDays      baseFare     totalFare  seatsRemaining  \
# count  5.000000e+06  5.000000e+06  5.000000e+06    5.000000e+06
# mean   1.469112e-01  3.032033e+02  3.516310e+02    5.659033e+00
# std    3.540231e-01  1.950507e+02  2.093218e+02    2.935401e+00
# min    0.000000e+00  5.100000e+00  2.397000e+01    0.000000e+00
# 25%    0.000000e+00  1.674400e+02  2.056000e+02    3.000000e+00
# 50%    0.000000e+00  2.734900e+02  3.206000e+02    7.000000e+00
# 75%    0.000000e+00  4.037200e+02  4.576000e+02    8.000000e+00
# max    2.000000e+00  7.662330e+03  8.260610e+03    1.000000e+01
#
#        totalTravelDistance
# count         4.682132e+06
# mean          1.572933e+03
# std           8.391262e+02
# min           9.700000e+01
# 25%           8.620000e+02
# 50%           1.392000e+03
# 75%           2.353000e+03
# max           3.958000e+03

# %%
type(flight)
# Out:
# pandas.core.frame.DataFrame

# %%
flight.flightDate.unique()
# Out:
# array(['2022-04-17', '2022-04-18', '2022-04-19', '2022-04-20',
#        '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-24',
#        '2022-04-25', '2022-04-26', '2022-04-27', '2022-04-28',
#        '2022-04-29', '2022-04-30', '2022-05-01', '2022-05-02',
#        '2022-05-03', '2022-05-04', '2022-05-05', '2022-05-06',
#        '2022-05-07', '2022-05-08', '2022-05-09', '2022-05-10',
#        '2022-05-11', '2022-05-12', '2022-05-13', '2022-05-14',
#        '2022-05-15', '2022-05-16', '2022-05-17', '2022-05-18',
#        '2022-05-19', '2022-05-20', '2022-05-21', '2022-05-22',
#        '2022-05-23', '2022-05-24', '2022-05-25', '2022-05-26',
#        '2022-05-27', '2022-05-28', '2022-05-29', '2022-05-30',
#        '2022-05-31', '2022-06-01', '2022-06-02', '2022-06-03',
#        '2022-06-04', '2022-06-05', '2022-06-06', '2022-06-07',
#        '2022-06-08', '2022-06-09', '2022-06-10', '2022-06-11',
#        '2022-06-12', '2022-06-13', '2022-06-14', '2022-06-15',
# ...

# %%
flight.flightDate.nunique()
# Out:
# 69

# %%
flight.flightDate.value_counts()
# Out:
# flightDate
# 2022-05-03    120002
# 2022-05-10    113966
# 2022-05-04    110983
# 2022-04-26    107712
# 2022-05-11    107631
#                ...
# 2022-06-22     17537
# 2022-04-18     16524
# 2022-06-23      9041
# 2022-04-17      8258
# 2022-06-24      1951
# Name: count, Length: 69, dtype: int64

# %%
flight["flightDate"] = pd.to_datetime(flight["flightDate"])
may_flights = flight[flight["flightDate"].dt.month == 5]
may_flights.to_csv("itineraries_clear.csv", index=False)

print("Number of flights in May:", len(may_flights))
# Out:
# Number of flights in May: 2873519
